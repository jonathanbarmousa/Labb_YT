# %% [markdown]
# # Reading markdown files

# %%
from backend.constants import DATA_PATH

# Opening markdown files
md_path = tuple(DATA_PATH.glob("*.md")) 
md_path
# Out:
# (WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/An introduction to the vector database LanceDB.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/API trafiklab (1).md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/API trafiklab.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Azure static web app deploy react app.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Chat with your excel data - xlwings lite (1).md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Chat with your excel data - xlwings lite.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Course structure for Azure two weeks course.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Data platform course structure.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/data processing course  structure.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/data storytelling.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/dbt modeling snowflake.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/docker setup windows.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/FastAPI and scikit-learn API connect to streamlit frontend.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Fastapi CRUD app.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Hands on regularization.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/How does LLM work_.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Logistic regression hands on with scikit learn.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Logistic regression theory.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Modern data stack - deploy dockerized dashboard into Azure web app.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Modern data stack - dockerize your data pipeline.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Modern data stack - using dlt to extract and load api data to snowflake.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Packaging in python.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/pandas_read_excel.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/postgres sink.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Pydantic fundamentals.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Pydantic with gemini to structure output in a much neater way.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/pydanticAI chatbot.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/PydanticAI fundamentals - outputting structured pydantic model.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/pytest unit testing.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Python fundamentals.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/python intro.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Python_oop_1.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Serving PydanticAI Gemini Model with FastAPI Tutorial (1).md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Serving PydanticAI Gemini Model with FastAPI Tutorial.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - course structure.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - CRUD operations tutorial.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - dlt to load sakila data from SQLite into DuckDB.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - joins concepts.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - joins with sakila database tutorial.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - pandas and duckdb (1).md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - pandas and duckdb.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - Sakila BI dashboard using Evidence (1).md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - Sakila BI dashboard using Evidence.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - set theory part 2 (using Sakila) (1).md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - set theory part 2 (using Sakila).md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - setup duckdb.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - strings concepts.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - strings tutorial.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - subquery tutorial.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics course with DuckDB - views tutorial.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/SQL analytics with DuckDB - introduction.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/Terraform setup.md'),
#  WindowsPath('c:/Users/andre/Documents/github/rag_youtuber_project/data/XGBoost hands on tutorial for classification.md'))

# %%
# Checking amount of files
md_files = len(md_path)
md_files
# Out:
# 53

# %% [markdown]
# # Exploring knowledge base

# %%
import lancedb

db = lancedb.connect("knowledge_base")
db["transcripts"].to_pandas()
# Out:
#                                         transcript_id  \
# 0            Chat with your excel data - xlwings lite
# 1         Course structure for Azure two weeks course
# 2                      Data platform course structure
# 3                   data processing course  structure
# 4                                   data storytelling
# 5                              dbt modeling snowflake
# 6                                docker setup windows
# 7   FastAPI and scikit-learn API connect to stream...
# 8                                    Fastapi CRUD app
# 9                             Hands on regularization
# 10                                 How does LLM work_
# 11     Logistic regression hands on with scikit learn
# 12                         Logistic regression theory
# 13  Modern data stack - deploy dockerized dashboar...
# 14   Modern data stack - dockerize your data pipeline
# 15  Modern data stack - using dlt to extract and l...
# 16                                Packaging in python
# 17                                  pandas_read_excel
# 18                                      postgres sink
# 19                              Pydantic fundamentals
# 20  Pydantic with gemini to structure output in a ...
# 21                                 pydanticAI chatbot
# 22  PydanticAI fundamentals - outputting structure...
# 23                                pytest unit testing
# 24                                Python fundamentals
# 25                                       python intro
# 26                                       Python_oop_1
# 27  Serving PydanticAI Gemini Model with FastAPI T...
# 28  Serving PydanticAI Gemini Model with FastAPI T...
# 29  SQL analytics course with DuckDB - course stru...
# 30  SQL analytics course with DuckDB - CRUD operat...
# 31  SQL analytics course with DuckDB - dlt to load...
# 32  SQL analytics course with DuckDB - joins concepts
# 33  SQL analytics course with DuckDB - joins with ...
# 34  SQL analytics course with DuckDB - pandas and ...
# 35  SQL analytics course with DuckDB - pandas and ...
# 36  SQL analytics course with DuckDB - Sakila BI d...
# 37  SQL analytics course with DuckDB - Sakila BI d...
# 38  SQL analytics course with DuckDB - set theory ...
# 39  SQL analytics course with DuckDB - set theory ...
# 40    SQL analytics course with DuckDB - setup duckdb
# 41  SQL analytics course with DuckDB - strings con...
# 42  SQL analytics course with DuckDB - strings tut...
# 43  SQL analytics course with DuckDB - subquery tu...
# 44  SQL analytics course with DuckDB - views tutorial
# 45           SQL analytics with DuckDB - introduction
# 46                                    Terraform setup
# 47       XGBoost hands on tutorial for classification
# 48     An introduction to the vector database LanceDB
# 49                                  API trafiklab (1)
# 50                                      API trafiklab
# 51              Azure static web app deploy react app
# 52       Chat with your excel data - xlwings lite (1)
#
#                                                source  \
# 0            Chat with your excel data - xlwings lite
# 1         Course structure for Azure two weeks course
# 2                      Data platform course structure
# 3                   data processing course  structure
# 4                                   data storytelling
# 5                              dbt modeling snowflake
# 6                                docker setup windows
# 7   FastAPI and scikit-learn API connect to stream...
# 8                                    Fastapi CRUD app
# 9                             Hands on regularization
# 10                                 How does LLM work_
# 11     Logistic regression hands on with scikit learn
# 12                         Logistic regression theory
# 13  Modern data stack - deploy dockerized dashboar...
# 14   Modern data stack - dockerize your data pipeline
# 15  Modern data stack - using dlt to extract and l...
# 16                                Packaging in python
# 17                                  pandas_read_excel
# 18                                      postgres sink
# 19                              Pydantic fundamentals
# 20  Pydantic with gemini to structure output in a ...
# 21                                 pydanticAI chatbot
# 22  PydanticAI fundamentals - outputting structure...
# 23                                pytest unit testing
# 24                                Python fundamentals
# 25                                       python intro
# 26                                       Python_oop_1
# 27  Serving PydanticAI Gemini Model with FastAPI T...
# 28  Serving PydanticAI Gemini Model with FastAPI T...
# 29  SQL analytics course with DuckDB - course stru...
# 30  SQL analytics course with DuckDB - CRUD operat...
# 31  SQL analytics course with DuckDB - dlt to load...
# 32  SQL analytics course with DuckDB - joins concepts
# 33  SQL analytics course with DuckDB - joins with ...
# 34  SQL analytics course with DuckDB - pandas and ...
# 35  SQL analytics course with DuckDB - pandas and ...
# 36  SQL analytics course with DuckDB - Sakila BI d...
# 37  SQL analytics course with DuckDB - Sakila BI d...
# 38  SQL analytics course with DuckDB - set theory ...
# 39  SQL analytics course with DuckDB - set theory ...
# 40    SQL analytics course with DuckDB - setup duckdb
# 41  SQL analytics course with DuckDB - strings con...
# 42  SQL analytics course with DuckDB - strings tut...
# 43  SQL analytics course with DuckDB - subquery tu...
# 44  SQL analytics course with DuckDB - views tutorial
# 45           SQL analytics with DuckDB - introduction
# 46                                    Terraform setup
# 47       XGBoost hands on tutorial for classification
# 48     An introduction to the vector database LanceDB
# 49                                  API trafiklab (1)
# 50                                      API trafiklab
# 51              Azure static web app deploy react app
# 52       Chat with your excel data - xlwings lite (1)
#
#                                               content  \
# 0   # Chat with your excel data - xlwings lite\n\n...
# 1   # Course structure for Azure two weeks course\...
# 2   # Data platform course structure\n\n[00:00:00]...
# 3   # data processing course structure\n\n**Kokchu...
# 4   # data storytelling\n\n[00:00:00] Hello and we...
# 5   # dbt modeling snowflake\n\n**Kokchun Giang:**...
# 6   # docker setup windows\n\n[00:00:00] Hello and...
# 7   # FastAPI and scikit-learn API connect to stre...
# 8   # Fastapi CRUD app\n\n**Kokchun Giang:** [00:0...
# 9   # Hands on regularization\n\n[00:00:00] Hello ...
# 10  # How does LLM work?\n\n[00:00:00] Hello and w...
# 11  # Logistic regression hands on with scikit lea...
# 12  # Logistic regression theory\n\n[00:00:00] Hel...
# 13  # Modern data stack - deploy dockerized dashbo...
# 14  # Modern data stack - dockerize your data pipe...
# 15  # Modern data stack - using dlt to extract and...
# 16  # Packaging in python\n\n[00:00:00] Hello and ...
# 17  # pandas\_read\_excel\n\n[00:00:00] Hello and ...
# 18  # postgres sink\n\n[00:00:00] Hello and welcom...
# 19  # Pydantic fundamentals\n\n[00:00:00] Hello an...
# 20  # Pydantic with gemini to structure output in ...
# 21  # pydanticAI chatbot\n\n[00:00:00] Hello and w...
# 22  # PydanticAI fundamentals - outputting structu...
# 23  # pytest unit testing\n\n[00:00:00] Hello and ...
# 24  # Python fundamentals\n\n[00:00:00] Hello and ...
# 25  # python intro\n\n[00:00:00] Hello and welcome...
# 26  # Python\_oop\_1\n\n**kokchun:** [00:00:00] He...
# 27  # Serving PydanticAI Gemini Model with FastAPI...
# 28  # Serving PydanticAI Gemini Model with FastAPI...
# 29  # SQL analytics course with DuckDB - course st...
# 30  # SQL analytics course with DuckDB - CRUD oper...
# 31  # SQL analytics course with DuckDB - dlt to lo...
# 32  # SQL analytics course with DuckDB - joins con...
# 33  # SQL analytics course with DuckDB - joins wit...
# 34  # SQL analytics course with DuckDB - pandas an...
# 35  # SQL analytics course with DuckDB - pandas an...
# 36  # SQL analytics course with DuckDB - Sakila BI...
# 37  # SQL analytics course with DuckDB - Sakila BI...
# 38  # SQL analytics course with DuckDB - set theor...
# 39  # SQL analytics course with DuckDB - set theor...
# 40  # SQL analytics course with DuckDB - setup duc...
# 41  # SQL analytics course with DuckDB - strings c...
# 42  # SQL analytics course with DuckDB - strings t...
# 43  # SQL analytics course with DuckDB - subquery ...
# 44  # SQL analytics course with DuckDB - views tut...
# 45  # SQL analytics with DuckDB - introduction\n\n...
# 46  # Terraform setup\n\n[00:00:00] Hello and welc...
# 47  # XGBoost hands on tutorial for classification...
# 48  # An introduction to the vector database Lance...
# 49  # API trafiklab\n\n[00:00:00] Hello and welcom...
# 50  # API trafiklab\n\n[00:00:00] Hello and welcom...
# 51  # Azure static web app deploy react app\n\n[00...
# 52  # Chat with your excel data - xlwings lite\n\n...
#
#                                             embedding
# 0   [-0.0071265996, 0.020476552, 0.017235534, -0.0...
# 1   [0.0015313567, 0.012794174, 0.016358217, -0.07...
# 2   [0.010435624, -0.0016020014, 0.011163727, -0.0...
# 3   [0.0032914313, 0.01059015, 0.009196502, -0.064...
# 4   [-0.011316549, 0.016874935, 0.012392512, -0.08...
# 5   [-0.010636117, 0.01212832, 0.029030465, -0.086...
# 6   [-0.0034482135, 0.010729573, 0.016939094, -0.0...
# 7   [-0.017560659, 0.009985835, 0.01749353, -0.085...
# 8   [-0.012556567, -0.01593715, 0.022671303, -0.07...
# 9   [-0.009709013, 6.357031e-05, 0.023912106, -0.0...
# 10  [-0.027908303, 0.017137818, 0.023856219, -0.06...
# 11  [-0.0066825696, 0.002244388, 0.011106265, -0.0...
# 12  [-0.008146983, -0.00016716555, 0.011266027, -0...
# 13  [-0.0075815883, 0.02116889, 0.027429571, -0.10...
# 14  [0.0027987233, 0.014228618, 0.027441906, -0.09...
# 15  [-0.00826649, 0.019363934, 0.016988434, -0.080...
# 16  [-0.0150246415, 0.0042777252, 0.038052212, -0....
# 17  [-0.0038475876, 0.0054737586, 0.024301918, -0....
# 18  [0.007228276, 0.021961471, 0.031665433, -0.088...
# 19  [-0.017777685, -0.01204192, 0.02006065, -0.059...
# 20  [-0.01512796, -0.003907627, 0.015176425, -0.07...
# 21  [-0.012143856, -0.001205422, 0.013563879, -0.0...
# 22  [-0.033087507, 0.0036856267, 0.02514256, -0.07...
# 23  [-0.014343338, 0.0007622975, 0.030120881, -0.0...
# 24  [-0.011976539, 0.0025688808, 0.015519834, -0.0...
# 25  [-0.0110368235, -0.0020397531, 0.012955041, -0...
# 26  [-0.008043373, -0.011165032, 0.031197485, -0.0...
# 27  [-0.018388461, -0.006911759, 0.015190295, -0.0...
# 28  [-0.018388461, -0.006911759, 0.015190295, -0.0...
# 29  [0.0023245383, -0.0029253534, 0.0036489798, -0...
# 30  [-0.018357037, -0.0009783215, 0.025988214, -0....
# 31  [-0.0066205882, -0.0075128363, 0.019882608, -0...
# 32  [-0.027722066, -0.016966412, 0.012043696, -0.0...
# 33  [-0.022949534, -0.022863599, 0.013395227, -0.0...
# 34  [-0.009578243, -0.011996515, 0.012965736, -0.0...
# 35  [-0.009578243, -0.011996515, 0.012965736, -0.0...
# 36  [0.0055291746, -0.004573792, 0.019058505, -0.0...
# 37  [0.0055291746, -0.004573792, 0.019058505, -0.0...
# 38  [-0.027204884, -0.023552606, 0.019531347, -0.0...
# 39  [-0.027204884, -0.023552606, 0.019531347, -0.0...
# 40  [-0.008761382, -0.0034869136, 0.01760935, -0.0...
# 41  [-0.02525857, -0.011639317, 0.004399808, -0.07...
# 42  [-0.021185221, -0.0025146175, 0.01119325, -0.0...
# 43  [-0.012517108, -0.014230472, -0.0019505646, -0...
# 44  [-0.027096331, -0.0073001576, 0.0048975083, -0...
# 45  [-0.028552804, -0.0118231885, 0.00639494, -0.0...
# 46  [-0.004057311, 0.01868715, 0.01563467, -0.0808...
# 47  [-0.004887973, 0.008207077, 0.013008361, -0.09...
# 48  [-0.038686633, 0.0036908067, 0.02178414, -0.07...
# 49  [-0.006812348, -0.0044766036, 0.014319714, -0....
# 50  [-0.006812348, -0.0044766036, 0.014319714, -0....
# 51  [-0.012295628, 0.015832268, 0.025340993, -0.09...
# 52  [-0.0071265996, 0.020476552, 0.017235534, -0.0...
