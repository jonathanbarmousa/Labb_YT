# %% [markdown]
# # Reading markdown files

# %%
from backend.constants import DATA_PATH

# Opening markdown files
md_path = tuple(DATA_PATH.glob("*.md")) 
md_path
# Out:
# (PosixPath('/Users/jonathanbarmousa/Desktop/Rag-labb/Labb_YT/data/Fastapi CRUD app.md'),
#  PosixPath('/Users/jonathanbarmousa/Desktop/Rag-labb/Labb_YT/data/SQL analytics course with DuckDB - set theory part 2 (using Sakila) (1).md'),
#  PosixPath('/Users/jonathanbarmousa/Desktop/Rag-labb/Labb_YT/data/Python fundamentals.md'),
#  PosixPath('/Users/jonathanbarmousa/Desktop/Rag-labb/Labb_YT/data/Packaging in python.md'),
#  PosixPath('/Users/jonathanbarmousa/Desktop/Rag-labb/Labb_YT/data/Pydantic fundamentals.md'),
#  PosixPath('/Users/jonathanbarmousa/Desktop/Rag-labb/Labb_YT/data/SQL analytics course with DuckDB - joins with sakila database tutorial.md'),
#  PosixPath('/Users/jonathanbarmousa/Desktop/Rag-labb/Labb_YT/data/Pydantic with gemini to structure output in a much neater way.md'),
#  PosixPath('/Users/jonathanbarmousa/Desktop/Rag-labb/Labb_YT/data/pydanticAI chatbot.md'),
# ...

# %%
# Checking amount of files
md_files = len(md_path)
md_files
# Out:
# 53

# %% [markdown]
# # Exploring knowledge base

# %%
import lancedb

db = lancedb.connect("knowledge_base")
db["transcripts"].to_pandas()
# Out:
#                                         transcript_id  \
# 0                                    Fastapi CRUD app
# 1   SQL analytics course with DuckDB - set theory ...
# 2                                 Python fundamentals
# 3                                 Packaging in python
# 4                               Pydantic fundamentals
# 5   SQL analytics course with DuckDB - joins with ...
# 6   Pydantic with gemini to structure output in a ...
# 7                                  pydanticAI chatbot
# 8   SQL analytics course with DuckDB - joins concepts
# 9                                docker setup windows
# 10  SQL analytics course with DuckDB - Sakila BI d...
# 11    SQL analytics course with DuckDB - setup duckdb
# 12  SQL analytics course with DuckDB - strings con...
# 13                         Logistic regression theory
# 14                                  API trafiklab (1)
# 15  SQL analytics course with DuckDB - pandas and ...
# ...

# %% [markdown]
# # Exploring deployed function app

# %%
import requests
import os 
from dotenv import load_dotenv

load_dotenv()
url = f"https://ragyoutuber11.azurewebsites.net/api/function_app/rag/query?code={os.getenv('FUNCTION_APP_API')}"
response = requests.post(url, json={"prompt": "Snowflake"})
response
# Out:
# <Response [404]>

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/Rag-labb/.venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
# ...
